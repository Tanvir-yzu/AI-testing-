# %%
import pandas as pd   # make sure this is at the top of your notebook

# If your file is named 'std_rez.xlsx'
df = pd.read_excel("std_rez.xlsx")

# Show first 5 rows
df.head()
# Out:
#    Student ID            Name  Gender  Age            Course  \
# 0           1     Grace Smith    Male   25  Computer Science
# 1           2    Eva Anderson    Male   25           English
# 2           3       Ian Brown    Male   20           Science
# 3           4  Frank Anderson    Male   21         Economics
# 4           5     David White  Female   20  Computer Science
#
#                             Email   Contact Number  Math  Science  History  \
# 0     grace.smith1@university.edu  +1-202-721-6097    81       54       92
# 1    eva.anderson2@university.edu  +1-202-777-5442    78       68       53
# 2       ian.brown3@university.edu  +1-202-350-9137    87       58       57
# 3  frank.anderson4@university.edu  +1-202-299-2750    76       61       67
# 4     david.white5@university.edu  +1-202-269-6053    97       96       88
#
#    English  Computer Science
# 0      100                99
# 1       86                64
# 2       66                98
# ...

# %%
df.sort_values("Age")  
df.head()
# Out:
#    Student ID            Name  Gender  Age            Course  \
# 0           1     Grace Smith    Male   25  Computer Science
# 1           2    Eva Anderson    Male   25           English
# 2           3       Ian Brown    Male   20           Science
# 3           4  Frank Anderson    Male   21         Economics
# 4           5     David White  Female   20  Computer Science
#
#                             Email   Contact Number  Math  Science  History  \
# 0     grace.smith1@university.edu  +1-202-721-6097    81       54       92
# 1    eva.anderson2@university.edu  +1-202-777-5442    78       68       53
# 2       ian.brown3@university.edu  +1-202-350-9137    87       58       57
# 3  frank.anderson4@university.edu  +1-202-299-2750    76       61       67
# 4     david.white5@university.edu  +1-202-269-6053    97       96       88
#
#    English  Computer Science
# 0      100                99
# 1       86                64
# 2       66                98
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 985.5 kB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.1 MB 1.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.1 MB 1.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.1 MB 1.8 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.1 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 2.0 MB/s eta 0:00:03
# ...

# %%
import matplotlib.pyplot as plt

df["Age"].plot(kind="hist")   # histogram
df.plot(x="Name", y="Age", kind="bar")   # bar chart
plt.show()

# %%
df.head()
# Out:
#    Student ID            Name  Gender  Age            Course  \
# 0           1     Grace Smith    Male   25  Computer Science
# 1           2    Eva Anderson    Male   25           English
# 2           3       Ian Brown    Male   20           Science
# 3           4  Frank Anderson    Male   21         Economics
# 4           5     David White  Female   20  Computer Science
#
#                             Email   Contact Number  Math  Science  History  \
# 0     grace.smith1@university.edu  +1-202-721-6097    81       54       92
# 1    eva.anderson2@university.edu  +1-202-777-5442    78       68       53
# 2       ian.brown3@university.edu  +1-202-350-9137    87       58       57
# 3  frank.anderson4@university.edu  +1-202-299-2750    76       61       67
# 4     david.white5@university.edu  +1-202-269-6053    97       96       88
#
#    English  Computer Science  NewCol
# 0      100                99      50
# 1       86                64      50
# ...
